# %% [markdown]
# # **at first read README.md file to learn how to preparing the dataset.**

# %% [markdown]
# #install the yolov5 from github:

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16725, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 16725 (delta 12), reused 17 (delta 5), pack-reused 16679
# Receiving objects: 100% (16725/16725), 15.31 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (11491/11491), done.

# %% [markdown]
# # go to yolov5 dir and install the requirements:

# %%
# %cd /content/yolov5

# !pip install -r requirements.txt
# Out:
# /content/yolov5

# %% [markdown]
# # install roboflow to get dataset:

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
# ...

# %% [markdown]
# # get the dataset from roboflow:

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your_api_key")
project = rf.workspace("your_work_space_name").project("your_project_name")
version = project.version(1)
dataset = version.download("yolov5")

# %% [markdown]
# # train the model:

# %%
# !python train.py --img 416 --batch 16 --epochs 30 --data your_yaml_file_path --weights yolov5s.pt

# %% [markdown]
# # ziping the trained file:

# %%
# !zip -r train.zip /content/yolov5/runs/train/

# %% [markdown]
# # use the model on webcam:
#
# after the download the zipng file put it in yolov5 folder and unzip it then go to teminal or cmd  and run the command:

# %%
python3 detect.py --source 0 --weights runs/train/exp/weights/best.pt
# Out:
#   File "<ipython-input-3-0c120373eac1>", line 1
#     python3 detect.py --source 0 --weights runs/train/exp/weights/best.pt
#             ^
# SyntaxError: invalid syntax
